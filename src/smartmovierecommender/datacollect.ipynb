# %%
#open api 
#import API key 
import requests
import json
with open('/Users/rachnarawalpally/dsan5400-project/api_key.json') as f:
    keys = json.load(f)
API_KEY = keys['OMDb API']

# %%
#testing this works 

import requests

movie_title = "The Hunger Games"

# OMDb API endpoint to search by title
url = f"http://www.omdbapi.com/?t={movie_title}&apikey={API_KEY}"

# Send a request to the API
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the JSON data
    movie_data = response.json()
    
    # Check if the movie was found
    if movie_data['Response'] == 'True':
        # Display the movie details
        print(f"Title: {movie_data['Title']}")
        print(f"Year: {movie_data['Year']}")
        print(f"Genre: {movie_data['Genre']}")
        print(f"Rating: {movie_data['imdbRating']}")
        print(f"Plot: {movie_data['Plot']}")
    else:
        print(f"Movie not found: {movie_data['Error']}")
else:
    print("Failed to fetch data from OMDb API.")
# Out:
# Title: The Hunger Games
# Year: 2012
# Genre: Action, Adventure, Sci-Fi
# Rating: 7.2
# Plot: Katniss Everdeen voluntarily takes her younger sister's place in the Hunger Games: a televised competition in which two teenagers from each of the twelve Districts of Panem are chosen at random to fight to the death.

# %%
import requests
from bs4 import BeautifulSoup

def get_movie_titles_from_wikipedia(url):
    #fetch the web page content
    response = requests.get(url)
    
    #parse the HTML content with BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    #find all tables in the page (looking specifically for the one that lists the movies)
    tables = soup.find_all('table', {'class': 'wikitable'})

    movie_titles = []

    #loop through the tables and extract movie titles
    for table in tables:
        #find all rows in the table
        rows = table.find_all('tr')
        
        for row in rows:
            #get all table data (td) in the row
            columns = row.find_all('td')
            
            if columns:
                #check if there is a title in the first column (typically the movie title)
                title_column = columns[0] 
                if title_column:
                    title = title_column.get_text(strip=True)
                    movie_titles.append(title)

    return movie_titles

#the link to get 
url = "https://en.wikipedia.org/wiki/List_of_American_films_of_2006"
movies = get_movie_titles_from_wikipedia(url)

#print movie titles
for movie_2006 in movies[:200]:
    if not movie_2006.isdigit():
        print(movie_2006)
# Out:
# Pirates of the Caribbean: Dead Man's Chest
# Night at the Museum
# Cars
# X-Men: The Last Stand
# The Da Vinci Code
# Superman Returns
# Happy Feet
# Ice Age: The Meltdown
# Casino Royale
# The Pursuit of Happyness
# Grandma's Boy
# Hoodwinked!
# Last Holiday
# Tristan and Isolde
# High School Musical
# Underworld: Evolution
# Big Momma's House 2
# Nanny McPhee
# When a Stranger Calls
# Final Destination 3
# Firewall
# The Pink Panther
# Eight Below
# Freedomland
# Madea's Family Reunion
# Running Scared
# Aquamarine
# Dave Chappelle's Block Party
# Ultraviolet
# Game 6
# The Hills Have Eyes
# The Libertine
# The Shaggy Dog
# Thank You for Smoking
# V for Vendetta
# Larry the Cable Guy: Health Inspector
# The Secret
# Stay Alive
# Unidentified
# Basic Instinct 2
# Ice Age: The Meltdown
# Slither
# Friends with Money
# Lucky Number Slevin
# Phat Girlz
# Take the Lead
# The Notorious Bettie Page
# Scary Movie 4
# The Wild
# The Sentinel
# Silent Hill
# RV
# Stick It
# United 93
# ...

# %%
movie_title = """
Pirates of the Caribbean: Dead Man's Chest
Night at the Museum
Cars
X-Men: The Last Stand
The Da Vinci Code
Superman Returns
Happy Feet
Ice Age: The Meltdown
Casino Royale
The Pursuit of Happyness
Grandma's Boy
Hoodwinked!
Last Holiday
Tristan and Isolde
High School Musical
Underworld: Evolution
Big Momma's House 2
Nanny McPhee
When a Stranger Calls
Final Destination 3
Firewall
The Pink Panther
Eight Below
Freedomland
Madea's Family Reunion
Running Scared
Aquamarine
Dave Chappelle's Block Party
Ultraviolet
Game 6
The Hills Have Eyes
The Libertine
The Shaggy Dog
Thank You for Smoking
V for Vendetta
Larry the Cable Guy: Health Inspector
The Secret
Stay Alive
Unidentified
Basic Instinct 2
Ice Age: The Meltdown
Slither
Friends with Money
Lucky Number Slevin
Phat Girlz
Take the Lead
The Notorious Bettie Page
Scary Movie 4
The Wild
The Sentinel
Silent Hill
RV
Stick It
United 93
Art School Confidential
Hoot
Mission: Impossible III
Poseidon
Over the Hedge
See No Evil
A Prairie Home Companion
Garfield: A Tail of Two Kitties
The Lake House
Loverboy
Nacho Libre
Waist Deep
A Scanner Darkly
You, Me and Dupree
Lady in the Water
Monster House
My Super Ex-Girlfriend
John Tucker Must Die
Miami Vice
Scoop
The Descent
The Night Listener
Talladega Nights: The Ballad of Ricky Bobby
Pulse
Step Up
Zoom
The Illusionist
Material Girls
Snakes on a Plane
Trust the Man
How to Eat Fried Worms
Idlewild
Invincible
Crossover
Idiocracy
The Wicker Man
Hollywoodland
Everyone's Hero
Gridiron Gang
Haven
The Last Kiss
Bandidas
Jet Li's Fearless
Flyboys
Jackass Number Two
The Science of Sleep
The Guardian
A Guide to Recognizing Your Saints
Open Season
School for Scoundrels
Employee of the Month
Little Children
The Queen
The Texas Chainsaw Massacre: The Beginning
Infamous
Man of the Year
The Marine
One Night with the King
Flicka
Marie Antoinette
The Prestige
Catch a Fire
Death of a President
Dirty Sanchez: the Movie
Dixie Chicks: Shut Up and Sing
Running with Scissors
Saw III
Flushed Away
The Santa Clause 3: The Escape Clause
Unknown
Volver
Come Early Morning
Harsh Times
The Return
Stranger Than Fiction
Candy
Casino Royale
For Your Consideration
Fast Food Nation
Happy Feet
Let's Go to Prison
Déjà Vu
The Fountain
Tenacious D in The Pick of Destiny
"""


movie_titles_2006 = [movie.strip() for movie in movie_title.strip().split("\n")]

#print the formatted Python list
print("movie_titles = [")
for title in movie_titles_2006:
    print(f'    "{title}",')
print("]")
# Out:
# movie_titles = [
#     "Pirates of the Caribbean: Dead Man's Chest",
#     "Night at the Museum",
#     "Cars",
#     "X-Men: The Last Stand",
#     "The Da Vinci Code",
#     "Superman Returns",
#     "Happy Feet",
#     "Ice Age: The Meltdown",
#     "Casino Royale",
#     "The Pursuit of Happyness",
#     "Grandma's Boy",
#     "Hoodwinked!",
#     "Last Holiday",
#     "Tristan and Isolde",
#     "High School Musical",
#     "Underworld: Evolution",
#     "Big Momma's House 2",
#     "Nanny McPhee",
#     "When a Stranger Calls",
#     "Final Destination 3",
#     "Firewall",
#     "The Pink Panther",
#     "Eight Below",
#     "Freedomland",
#     "Madea's Family Reunion",
#     "Running Scared",
#     "Aquamarine",
#     "Dave Chappelle's Block Party",
#     "Ultraviolet",
#     "Game 6",
#     "The Hills Have Eyes",
#     "The Libertine",
#     "The Shaggy Dog",
#     "Thank You for Smoking",
#     "V for Vendetta",
#     "Larry the Cable Guy: Health Inspector",
# ...

# %%
import requests
import csv

#list of movies 
movie_titles = movie_titles_2006

#save to csv file
output_file = "movies_2006.csv"

#open csv 
with open(output_file, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    #headers
    writer.writerow(["Title", "Year", "Genre","Runtime", "Director", "Writer","Actors","Rated","Rating", "Awards","Descrption"])

    for movie_title in movie_titles:
        #ombd search 
        url = f"http://www.omdbapi.com/?t={movie_title}&apikey={API_KEY}"
        # Send a request to the API
        response = requests.get(url)
        #check if the request was successful
        if response.status_code == 200: 
        #parse the JSON data
            movie_data = response.json()
    
    #check if the movie was found
        if movie_data['Response'] == 'True':
            writer.writerow([
        #display the movie details
                movie_data.get('Title', 'N/A'),
                    movie_data.get('Year', 'N/A'),
                    movie_data.get('Genre', 'N/A'),
                    movie_data.get('Runtime', 'N/A'),
                    movie_data.get('Director', 'N/A'),
                    movie_data.get('Writer', 'N/A'),
                    movie_data.get('Actors', 'N/A'),
                    movie_data.get('Rated', 'N/A'),
                    movie_data.get('imdbRating', 'N/A'),
                    movie_data.get('Awards', 'N/A'),
                    movie_data.get('Plot', 'N/A')
            ])
        else:
            print(f"Movie not found: {movie_data['Error']}")
    else:
        print("cant fetch movie data")
print(f"{output_file}")
# Out:
# Movie not found: Movie not found!
# cant fetch movie data
# movies_2006.csv

# %%
def get_movie_titles_from_wikipedia(url):
    #fetch the web page content
    response = requests.get(url)
    
    #parse the HTML content with BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    #find all tables in the page (looking specifically for the one that lists the movies)
    tables = soup.find_all('table', {'class': 'wikitable'})

    movie_titles = []

    #loop through the tables and extract movie titles
    for table in tables:
        #find all rows in the table
        rows = table.find_all('tr')
        
        for row in rows:
            #get all table data (td) in the row
            columns = row.find_all('td')
            
            if columns:
                #check if there is a title in the first column (typically the movie title)
                title_column = columns[0] 
                if title_column:
                    title = title_column.get_text(strip=True)
                    movie_titles.append(title)

    return movie_titles

#the link to get 
url = "https://en.wikipedia.org/wiki/List_of_American_films_of_2007"
movies = get_movie_titles_from_wikipedia(url)

#print movie titles
for movie_2007 in movies[:300]:
    if not movie_2007.isdigit():
        print(movie_2007)
# Out:
# Spider-Man 3
# Shrek the Third
# Transformers
# Pirates of the Caribbean: At World's End
# Harry Potter and the Order of the Phoenix
# I Am Legend
# The Bourne Ultimatum
# National Treasure: Book of Secrets
# Alvin and the Chipmunks
# Freedom Writers
# Happily N'Ever After
# Three
# Arthur and the Invisibles
# Primeval
# Stomp the Yard
# Catch and Release
# Epic Movie
# Seraphim Falls
# Smokin' Aces
# Factory Girl
# The Messengers
# The Situation
# Norbit
# Music and Lyrics
# Starter for 10
# Bridge to Terabithia
# Ghost Rider
# The Astronaut Farmer
# The Number 23
# Reno 911!: Miami
# Wild Hogs
# Zodiac
# The Ultimate Gift
# The Namesake
# I Think I Love My Wife
# Premonition
No Country for Old Men
P2
Love in the Time of Cholera
Margot at the Wedding
Mr. Magorium's Wonder Emporium
Enchanted
Hitman
I'm Not There
The Mist
This Christmas
The Diving Bell and the Butterfly
Tony n' Tina's Wedding: The Movie
Atonement
The Golden Compass
Grace Is Gone
Noëlle
Revolver
I Am Legend
The Kite Runner
Youth Without Youth
National Treasure: Book of Secrets
P.S. I Love You
Sweeney Todd: The Demon Barber of Fleet Street
Walk Hard: The Dewey Cox Story
The Bucket List
The Great Debaters
St Trinian's
The Water Horse: Legend of the Deep
"""


movie_titles_2007 = [movie.strip() for movie in movie_title.strip().split("\n")]

#print the formatted Python list
print("movie_titles = [")
for title in movie_titles_2007:
    print(f'    "{title}",')
print("]")
# Out:
# movie_titles = [
#     "Spider-Man 3",
#     "Shrek the Third",
#     "Transformers",
#     "Pirates of the Caribbean: At World's End",
#     "Harry Potter and the Order of the Phoenix",
#     "I Am Legend",
#     "The Bourne Ultimatum",
#     "National Treasure: Book of Secrets",
#     "Alvin and the Chipmunks",
#     "Freedom Writers",
#     "Happily N'Ever After",
#     "Three",
#     "Arthur and the Invisibles",
#     "Primeval",
#     "Stomp the Yard",
#     "Catch and Release",
#     "Epic Movie",
#     "Seraphim Falls",
#     "Smokin' Aces",
#     "Factory Girl",
#     "The Messengers",
#     "The Situation",
#     "Norbit",
#     "Music and Lyrics",
#     "Starter for 10",
#     "Bridge to Terabithia",
#     "Ghost Rider",
#     "The Astronaut Farmer",
#     "The Number 23",
#     "Reno 911!: Miami",
#     "Wild Hogs",
#     "Zodiac",
#     "The Ultimate Gift",
#     "The Namesake",
#     "I Think I Love My Wife",
#     "Premonition",
#     "The Wind That Shakes the Barley",
# ...

# %%
import requests
import csv

#list of movies 
movie_titles = movie_titles_2007

#save to csv file
output_file = "movies_2007.csv"

#open csv 
with open(output_file, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    #headers
    writer.writerow(["Title", "Year", "Genre","Runtime", "Director", "Writer","Actors","Rated","Rating", "Awards","Descrption"])

    for movie_title in movie_titles:
        #ombd search 
        url = f"http://www.omdbapi.com/?t={movie_title}&apikey={API_KEY}"
        # Send a request to the API
        response = requests.get(url)
        #check if the request was successful
        if response.status_code == 200: 
        #parse the JSON data
            movie_data = response.json()
    
    #check if the movie was found
        if movie_data['Response'] == 'True':
            writer.writerow([
        #display the movie details
                movie_data.get('Title', 'N/A'),
                    movie_data.get('Year', 'N/A'),
                    movie_data.get('Genre', 'N/A'),
                    movie_data.get('Runtime', 'N/A'),
                    movie_data.get('Director', 'N/A'),
                    movie_data.get('Writer', 'N/A'),
                    movie_data.get('Actors', 'N/A'),
                    movie_data.get('Rated', 'N/A'),
                    movie_data.get('imdbRating', 'N/A'),
                    movie_data.get('Awards', 'N/A'),
                    movie_data.get('Plot', 'N/A')
            ])
        else:
            print(f"Movie not found: {movie_data['Error']}")
    else:
        print("cant fetch movie data")
print(f"{output_file}")
# Out:
# Movie not found: Movie not found!
# Movie not found: Movie not found!
# Movie not found: Movie not found!
# Movie not found: Movie not found!
# cant fetch movie data
# movies_2006.csv

# %%
import csv 
import json 
#updates the csv file for 2007 movies to json so easier to get the score values 
with open('movies_2007.csv', 'r') as f:
    reader = csv.DictReader(f)
    data = list(reader)

# Convert to JSON and write to a file
with open('movies_2007.json', 'w') as f:
    json.dump(data, f, indent=4)

# %%
import requests
from bs4 import BeautifulSoup

#this is for 2008 
def get_movie_titles_from_wikipedia(url):
    #fetch the web page content
    response = requests.get(url)
    
    #parse the HTML content with BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    #find all tables in the page (looking specifically for the one that lists the movies)
    tables = soup.find_all('table', {'class': 'wikitable'})

    movie_titles = []

    #loop through the tables and extract movie titles
    for table in tables:
        #find all rows in the table
        rows = table.find_all('tr')
        
        for row in rows:
            #get all table data (td) in the row
            columns = row.find_all('td')
            
            if columns:
                #check if there is a title in the first column (typically the movie title)
                title_column = columns[0] 
                if title_column:
                    title = title_column.get_text(strip=True)
                    movie_titles.append(title)

    return movie_titles

#the link to get 
url = "https://en.wikipedia.org/wiki/List_of_American_films_of_2008"
movies = get_movie_titles_from_wikipedia(url)

#print movie titles
for movie_2007 in movies[:300]:
    if not movie_2007.isdigit():
        print(movie_2007)
# Out:
# The Dark Knight
# Iron Man
# Indiana Jones and the Kingdom of the Crystal Skull
# Hancock
# WALL-E
# Kung Fu Panda
# Twilight
# Madagascar: Escape 2 Africa
# Quantum of Solace
# Horton Hears a Who!
# A Bloody Aria
# In the Name of the King
# The Pirates Who Don't Do Anything: A VeggieTales Movie
# Cassandra's Dream
# Cloverfield
# Mad Money
# Teeth
# Meet the Spartans
# Minutemen
# Rambo
# Untraceable
# Hannah Montana and Miley Cyrus: Best of Both Worlds Concert
# Over Her Dead Body
# Strange Wilderness
# In Bruges
# Welcome Home Roscoe Jenkins
# Wild West Comedy Show: 30 Days and 30 Nights – Hollywood to the Heartland
# Jumper
# The Spiderwick Chronicles
# Step Up 2: The Streets
# Charlie Bartlett
# Sex and Death 101
# U2 3D
# Vantage Point
# Witless Protection
# Chicago 10
# City of Men
# The Other Boleyn Girl
# Penelope
# Semi-Pro
# The Bank Job
# College Road Trip
# Married Life
# Miss Pettigrew Lives for a Day
# Paranoid Park
# Snow Angels
# Dr. Seuss' Horton Hears a Who!
# ...

# %%
movie_title = """
The Dark Knight
Iron Man
Indiana Jones and the Kingdom of the Crystal Skull
Hancock
WALL-E
Kung Fu Panda
Twilight
Madagascar: Escape 2 Africa
Quantum of Solace
Horton Hears a Who!
A Bloody Aria
In the Name of the King
The Pirates Who Don't Do Anything: A VeggieTales Movie
Cassandra's Dream
Cloverfield
Mad Money
Teeth
Meet the Spartans
Minutemen
Rambo
Untraceable
Hannah Montana and Miley Cyrus: Best of Both Worlds Concert
Over Her Dead Body
Strange Wilderness
In Bruges
Welcome Home Roscoe Jenkins
Wild West Comedy Show: 30 Days and 30 Nights – Hollywood to the Heartland
Jumper
The Spiderwick Chronicles
Step Up 2: The Streets
Charlie Bartlett
Sex and Death 101
U2 3D
Vantage Point
Witless Protection
Chicago 10
City of Men
The Other Boleyn Girl
Penelope
Semi-Pro
The Bank Job
College Road Trip
Married Life
Miss Pettigrew Lives for a Day
# movie_titles = [
#     "The Dark Knight",
#     "Iron Man",
#     "Indiana Jones and the Kingdom of the Crystal Skull",
#     "Hancock",
#     "WALL-E",
#     "Kung Fu Panda",
#     "Twilight",
#     "Madagascar: Escape 2 Africa",
#     "Quantum of Solace",
#     "Horton Hears a Who!",
#     "A Bloody Aria",
#     "In the Name of the King",
#     "The Pirates Who Don't Do Anything: A VeggieTales Movie",
#     "Cassandra's Dream",
#     "Cloverfield",
#     "Mad Money",
#     "Teeth",
#     "Meet the Spartans",
#     "Minutemen",
#     "Rambo",
#     "Untraceable",
#     "Hannah Montana and Miley Cyrus: Best of Both Worlds Concert",
#     "Over Her Dead Body",
#     "Strange Wilderness",
#     "In Bruges",
#     "Welcome Home Roscoe Jenkins",
#     "Wild West Comedy Show: 30 Days and 30 Nights – Hollywood to the Heartland",
#     "Jumper",
#     "The Spiderwick Chronicles",
#     "Step Up 2: The Streets",
#     "Charlie Bartlett",
#     "Sex and Death 101",
#     "U2 3D",
# ...

# %%
#2008 

import requests
import csv

#list of movies 
movie_titles = movie_titles_2008

#save to csv file
output_file = "movies_2008.csv"

#open csv 
with open(output_file, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    #headers
    writer.writerow(["Title", "Year", "Genre","Runtime", "Director", "Writer","Actors","Rated","Rating", "Awards","Descrption"])

    for movie_title in movie_titles:
        #ombd search 
        url = f"http://www.omdbapi.com/?t={movie_title}&apikey={API_KEY}"
        # Send a request to the API
        response = requests.get(url)
        #check if the request was successful
        if response.status_code == 200: 
        #parse the JSON data
            movie_data = response.json()
    
    #check if the movie was found
        if movie_data['Response'] == 'True':
            writer.writerow([
        #display the movie details
                movie_data.get('Title', 'N/A'),
                    movie_data.get('Year', 'N/A'),
                    movie_data.get('Genre', 'N/A'),
                    movie_data.get('Runtime', 'N/A'),
                    movie_data.get('Director', 'N/A'),
                    movie_data.get('Writer', 'N/A'),
                    movie_data.get('Actors', 'N/A'),
                    movie_data.get('Rated', 'N/A'),
                    movie_data.get('imdbRating', 'N/A'),
                    movie_data.get('Awards', 'N/A'),
                    movie_data.get('Plot', 'N/A')
            ])
        else:
            print(f"Movie not found: {movie_data['Error']}")
    else:
        print("cant fetch movie data")
print(f"{output_file}")


import csv 
import json 
#updates the csv file for 2007 movies to json so easier to get the score values 
with open('movies_2008.csv', 'r') as f:
    reader = csv.DictReader(f)
    data = list(reader)

# Convert to JSON and write to a file
with open('movies_2008.json', 'w') as f:
    json.dump(data, f, indent=4)
# Out:
# Movie not found: Movie not found!
# Movie not found: Movie not found!
# Movie not found: Movie not found!
# Movie not found: Movie not found!
# cant fetch movie data
# movies_2008.csv

# %%
#for 2009 
def get_movie_titles_from_wikipedia(url):
    #fetch the web page content
    response = requests.get(url)
    
    #parse the HTML content with BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    #find all tables in the page (looking specifically for the one that lists the movies)
    tables = soup.find_all('table', {'class': 'wikitable'})

    movie_titles = []

    #loop through the tables and extract movie titles
    for table in tables:
        #find all rows in the table
        rows = table.find_all('tr')
        
        for row in rows:
            #get all table data (td) in the row
            columns = row.find_all('td')
            
            if columns:
                #check if there is a title in the first column (typically the movie title)
                title_column = columns[0] 
                if title_column:
                    title = title_column.get_text(strip=True)
Old Dogs
"""

movie_titles_2009 = [movie.strip() for movie in movie_title.strip().split("\n")]

#print the formatted Python list
print("movie_titles = [")
for title in movie_titles_2009:
    print(f'    "{title}",')
print("]")
# Out:
# movie_titles = [
#     "Avatar",
#     "Transformers: Revenge of the Fallen",
#     "Harry Potter and the Half-Blood Prince",
#     "The Twilight Saga: New Moon",
#     "Up",
#     "The Hangover",
#     "Star Trek",
#     "The Blind Side",
#     "Alvin and the Chipmunks: The Squeakquel",
#     "Sherlock Holmes",
#     "The Unborn",
#     "Hotel for Dogs",
#     "My Bloody Valentine 3D",
#     "Notorious",
#     "Paul Blart: Mall Cop",
#     "Ink",
#     "Inkheart",
#     "Killshot",
#     "Possession",
#     "Outlander",
#     "Underworld: Rise of the Lycans",
#     "Luck by Chance",
#     "New in Town",
#     "Taken",
#     "The Uninvited",
#     "Fanboys",
#     "He's Just Not That into You",
#     "Incendiary",
#     "The Pink Panther 2",
#     "Push",
#     "The Objective",
#     "Friday the 13th",
#     "Gomorrah",
#     "The International",
#     "The Secret of Moonacre",
#     "Two Lovers",
#     "Eleven Minutes",
#     "Fired Up",
#     "Madea Goes to Jail",
# ...

# %%
#list of movies 
movie_titles = movie_titles_2009

#save to csv file
output_file = "movies_2009.csv"

#open csv 
with open(output_file, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    #headers
    writer.writerow(["Title", "Year", "Genre","Runtime", "Director", "Writer","Actors","Rated","Rating", "Awards","Descrption"])

    for movie_title in movie_titles:
        #ombd search 
        url = f"http://www.omdbapi.com/?t={movie_title}&apikey={API_KEY}"
        # Send a request to the API
        response = requests.get(url)
        #check if the request was successful
        if response.status_code == 200: 
        #parse the JSON data
            movie_data = response.json()
    
    #check if the movie was found
        if movie_data['Response'] == 'True':
            writer.writerow([
        #display the movie details
                movie_data.get('Title', 'N/A'),
                    movie_data.get('Year', 'N/A'),
                    movie_data.get('Genre', 'N/A'),
                    movie_data.get('Runtime', 'N/A'),
                    movie_data.get('Director', 'N/A'),
                    movie_data.get('Writer', 'N/A'),
                    movie_data.get('Actors', 'N/A'),
                    movie_data.get('Rated', 'N/A'),
                    movie_data.get('imdbRating', 'N/A'),
                    movie_data.get('Awards', 'N/A'),
                    movie_data.get('Plot', 'N/A')
            ])
        else:
            print(f"Movie not found: {movie_data['Error']}")
    else:
        print("cant fetch movie data")
print(f"{output_file}")


import csv 
import json 
#updates the csv file for 2007 movies to json so easier to get the score values 
with open('movies_2009.csv', 'r') as f:
    reader = csv.DictReader(f)
    data = list(reader)

# Convert to JSON and write to a file
with open('movies_2009.json', 'w') as f:
    json.dump(data, f, indent=4)
# Out:
# Movie not found: Movie not found!
# Movie not found: Movie not found!
# Movie not found: Movie not found!
# Movie not found: Movie not found!
# Movie not found: Movie not found!
# Movie not found: Movie not found!
# Movie not found: Movie not found!
# Movie not found: Movie not found!
# Movie not found: Movie not found!
# cant fetch movie data
# movies_2009.csv

# %%
#for 2009 
def get_movie_titles_from_wikipedia(url):
    #fetch the web page content
    response = requests.get(url)
    
    #parse the HTML content with BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    #find all tables in the page (looking specifically for the one that lists the movies)
    tables = soup.find_all('table', {'class': 'wikitable'})

    movie_titles = []

    #loop through the tables and extract movie titles
    for table in tables:
        #find all rows in the table
        rows = table.find_all('tr')
        
        for row in rows:
            #get all table data (td) in the row
            columns = row.find_all('td')
            
            if columns:
                #check if there is a title in the first column (typically the movie title)
                title_column = columns[0] 
                if title_column:
                    title = title_column.get_text(strip=True)
                    movie_titles.append(title)

    return movie_titles

#the link to get 
url = "https://en.wikipedia.org/wiki/List_of_American_films_of_2010"
movies = get_movie_titles_from_wikipedia(url)

#print movie titles
movies_list = [movie_2010 for movie_2010 in movies[:350] if not movie_2010.isdigit()]
print(movies_list)
# Out:
# ['Toy Story 3', 'Alice in Wonderland', 'Iron Man 2', 'The Twilight Saga: Eclipse', 'Harry Potter and the Deathly Hallows – Part 1', 'Inception', 'Despicable Me', 'Shrek Forever After', 'How to Train Your Dragon', 'Tangled', 'Sweetgrass', 'Leap Year', 'Youth in Revolt', 'B*tch Slap', 'Crazy on the Outside', 'Waiting for Armageddon', 'Wonderful World', 'The Spy Next Door', '44 Inch Chest', 'Fish Tank', 'Legion', 'Tooth Fairy', 'Creation', 'The Girl on the Train', 'Soundtrack for a Revolution', 'To Save a Life', 'When in Rome', "Preacher's Kid", 'North Face', 'Saint John of Las Vegas', 'From Paris With Love', 'District 13: Ultimatum', 'Eyes Wide Open', 'Frozen', 'The Shinjuku Incident', 'Terribly Happy', 'My Name Is Khan', 'Videocracy', "Valentine's Day", 'The Wolfman', 'Lourdes', 'Shutter Island', 'The Good Guy', 'Happy Tears', 'The Red Baron', 'The Crazies', 'The Art of the Steal', 'Defendor', 'Easier with Practice', 'Formosa Betrayed', 'A Prophet', 'The Yellow Handkerchief', "Brookly
# ...

# %%
#list of movies 
movie_titles = movies_list

#save to csv file
output_file = "movies_2010.csv"

#open csv 
with open(output_file, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    #headers
    writer.writerow(["Title", "Year", "Genre","Runtime", "Director", "Writer","Actors","Rated","Rating", "Awards","Descrption"])

    for movie_title in movie_titles:
        #ombd search 
        url = f"http://www.omdbapi.com/?t={movie_title}&apikey={API_KEY}"
        # Send a request to the API
        response = requests.get(url)
        #check if the request was successful
        if response.status_code == 200: 
        #parse the JSON data
            movie_data = response.json()
    
    #check if the movie was found
        if movie_data['Response'] == 'True':
            writer.writerow([
        #display the movie details
                movie_data.get('Title', 'N/A'),
                    movie_data.get('Year', 'N/A'),
                    movie_data.get('Genre', 'N/A'),
                    movie_data.get('Runtime', 'N/A'),
                    movie_data.get('Director', 'N/A'),
                    movie_data.get('Writer', 'N/A'),
                    movie_data.get('Actors', 'N/A'),
                    movie_data.get('Rated', 'N/A'),
                    movie_data.get('imdbRating', 'N/A'),
                    movie_data.get('Awards', 'N/A'),
                    movie_data.get('Plot', 'N/A')
            ])
        else:
            print(f"Movie not found: {movie_data['Error']}")
    else:
        print("cant fetch movie data")
print(f"{output_file}")


import csv 
import json 
#updates the csv file for 2007 movies to json so easier to get the score values 
with open('movies_2010.csv', 'r') as f:
    reader = csv.DictReader(f)
    data = list(reader)

# Convert to JSON and write to a file
with open('movies_2010.json', 'w') as f:
    json.dump(data, f, indent=4)
# Out:
# Movie not found: Movie not found!
# Movie not found: Movie not found!
# Movie not found: Movie not found!
# Movie not found: Movie not found!
# Movie not found: Movie not found!
# Movie not found: Movie not found!
# Movie not found: Movie not found!
# Movie not found: Movie not found!
# Movie not found: Movie not found!
# Movie not found: Movie not found!
# cant fetch movie data
# movies_2010.csv
